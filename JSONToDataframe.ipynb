# %%
import json
import pandas as pd

file_path = '/Users/pookansmacbookpro/Documents/CEDT Computer Engineering/Sem1_2024/2110403_DataSci/Project/Data_2018-2023/2018/201800007'

import pandas as pd
import json

# Load JSON data (Replace 'file_path.json' with your actual file path)
def extract_data(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)

    # Extract relevant information from the JSON structure
    records = []

    item = data.get('abstracts-retrieval-response', {}).get('item', {})

    # Extract relevant fields with default values for missing data
    title = item.get('bibrecord', {}).get('head', {}).get('citation-title', '')
    abstract = item.get('bibrecord', {}).get('head', {}).get('abstracts', '')

    authors = []
    for author in data.get('abstracts-retrieval-response', {}).get('authors',{}).get('author',[]):
        name=author.get('preferred-name', {}).get('ce:indexed-name', '')
        if name:
            authors.append(name)

    # Initialize list to hold all classification codes
    subject_areas = []
    subject_area_groups = data.get('abstracts-retrieval-response', {}).get('subject-areas', {})
    if subject_area_groups and isinstance(subject_area_groups.get('subject-area'), list):
        for subject in subject_area_groups['subject-area']:
            if isinstance(subject, dict):
                subject_text = subject.get('@code')
                if subject_text:
                    subject_areas.append(subject_text)

    # Extract date of publication
    publication_date = data.get('abstracts-retrieval-response', {}).get('coredata', {}).get('prism:coverDate', {})

    # Process author affiliations
    affiliations = set()
    author_group = item.get('bibrecord', {}).get('head', {}).get('author-group', {})

    # Check if author_group is a list; if not, wrap it in a list to iterate over it
    if isinstance(author_group, dict):
        author_group = [author_group]  # Convert single dictionary to a list

    for group in author_group:
        affiliation = group.get('affiliation', {})
        affiliation_id = affiliation.get('@afid', '')
        if affiliation_id:
            affiliations.add(affiliation_id)


    # Extract citations/references
    references = []
    for reference in item.get('bibrecord', {}).get('tail', {}).get('bibliography', {}).get('reference', []):
        ref_title = reference.get('ref-info', {}).get('ref-title', {}).get('ref-titletext', '')
        if ref_title:
            references.append(ref_title)

    # Extract keywords
    keywords = []
    authkeywords = data.get('abstracts-retrieval-response', {}).get('authkeywords')

    if authkeywords and isinstance(authkeywords.get('author-keyword'), list):
        for keyword in authkeywords['author-keyword']:
            if isinstance(keyword, dict):
                keyword_text = keyword.get('$')
                if keyword_text:
                    keywords.append(keyword_text)


    records.append({
    'Title': title if title else None,
    'Abstract': abstract if abstract else None,
    'Author': "; ".join(authors) if authors else None,
    'Subject_Area': "; ".join(subject_areas) if subject_areas else None,
    'Publication_Date': publication_date if publication_date else None,
    'Affiliations_ID': "; ".join(affiliations) if affiliations else None,
    'References': "; ".join(references) if references else None,
    'Keywords': "; ".join(keywords) if keywords else None
})

    return records

data = extract_data(file_path)
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                Title Abstract  \
# 0  External beam radiotherapy in the treatment of...     None
#
#                                    Author Subject_Area Publication_Date  \
# 0  Johnstone C.; Ghia A.J.; Prayongrat A.         2700       2018-12-28
#
#                 Affiliations_ID  \
# 0  60012553; 60028190; 60015023
#
#                                           References Keywords
# 0  Then anatomy and pathways of bone metastasis; ...     None

# %%
import os
folder_path = '/Users/pookansmacbookpro/Documents/CEDT Computer Engineering/Sem1_2024/2110403_DataSci/Project/Data_2018-2023/2018/'
count=0
for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        count+=1
print(count)
# Out:
# 2792

# %%
import json
import os
import pandas as pd

# Define the folder path where your files are located
folder_path = '/Users/pookansmacbookpro/Documents/CEDT Computer Engineering/Sem1_2024/2110403_DataSci/Project/Data_2018-2023/2018/'

# Function to extract data from a single JSON file
def extract_data(file_path, filename):
    with open(file_path, 'r') as f:
        data = json.load(f)

    # Extract relevant information from the JSON structure
    records = []

    item = data.get('abstracts-retrieval-response', {}).get('item', {})

    # Extract relevant fields with default values for missing data
    title = item.get('bibrecord', {}).get('head', {}).get('citation-title', '')
    abstract = item.get('bibrecord', {}).get('head', {}).get('abstracts', '')

    authors = []
    for author in data.get('abstracts-retrieval-response', {}).get('authors', {}).get('author', []):
        name = author.get('preferred-name', {}).get('ce:indexed-name', '')
        if name:
            authors.append(name)

    # Initialize list to hold all classification codes
    subject_areas = []
    subject_area_groups = data.get('abstracts-retrieval-response', {}).get('subject-areas', {})
    if subject_area_groups and isinstance(subject_area_groups.get('subject-area'), list):
        for subject in subject_area_groups['subject-area']:
            if isinstance(subject, dict):
                subject_text = subject.get('@code')
                if subject_text:
                    subject_areas.append(subject_text)

    # Extract date of publication
    publication_date = data.get('abstracts-retrieval-response', {}).get('coredata', {}).get('prism:coverDate', '')

    # Process author affiliations
    affiliations = set()
    author_group = item.get('bibrecord', {}).get('head', {}).get('author-group', {})

    # Check if author_group is a list; if not, wrap it in a list to iterate over it
    if isinstance(author_group, dict):
        author_group = [author_group]  # Convert single dictionary to a list

    for group in author_group:
        affiliation = group.get('affiliation', {})
        affiliation_id = affiliation.get('@afid', '')
        if affiliation_id:
            affiliations.add(affiliation_id)

    # Extract citations/references
    references = []
    for reference in item.get('bibrecord', {}).get('tail', {}).get('bibliography', {}).get('reference', []):
        ref_title = reference.get('ref-info', {}).get('ref-title', {}).get('ref-titletext', '')
        if ref_title:
            references.append(ref_title)

    # Extract keywords
    keywords = []
    authkeywords = data.get('abstracts-retrieval-response', {}).get('authkeywords')

    if authkeywords and isinstance(authkeywords.get('author-keyword'), list):
        for keyword in authkeywords['author-keyword']:
            if isinstance(keyword, dict):
                keyword_text = keyword.get('$')
                if keyword_text:
                    keywords.append(keyword_text)

    records.append({
        'Title': str(title) if title else None,
        'Abstract': str(abstract) if abstract else None,
        'Author': "; ".join(authors) if authors else None,
        'Subject_Area': "; ".join(subject_areas) if subject_areas else None,
        'Publication_Date': str(publication_date) if publication_date else None,
        'Affiliations_ID': "; ".join(affiliations) if affiliations else None,
        'References': "; ".join(references) if references else None,
        'Keywords': "; ".join(keywords) if keywords else None,
        'Filename': str(filename)  # Add filename to each record
    })

    return records

# Loop through all JSON files in the specified folder and extract data
all_data = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    try:
        data = extract_data(file_path, filename)  # Pass filename to the function
        all_data.extend(data)
    except Exception as e:
        print(f"Error processing file: {filename}. Error: {e}")

# Create a DataFrame from the extracted data
df = pd.DataFrame(all_data)
df.shape
# Out:
# Error processing file: 201800075. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802173. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802529. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800089. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800029. Error: 'str' object has no attribute 'get'
# Error processing file: 201800823. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800649. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802464. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800959. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800966. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801075. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802657. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801213. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800109. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801222. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800114. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800113. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801296. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801230. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800112. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801034. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800115. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802611. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801582. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800837. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801380. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802330. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801317. Error: 'str' object has no attribute 'get'
# Error processing file: 201800838. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802308. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801594. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802576. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802318. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801937. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801364. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802697. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802655. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802262. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802639. Error: 'str' object has no attribute 'get'
# Error processing file: 201801874. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800390. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800355. Error: 'str' object has no attribute 'get'
# Error processing file: 201802279. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802481. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800587. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801860. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802285. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800970. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801802. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801006. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800867. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801174. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800856. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802530. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802154. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800491. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802164. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802163. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800036. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201800835. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201801313. Error: 'NoneType' object has no attribute 'get'
# Error processing file: 201802139. Error: 'NoneType' object has no attribute 'get'
# (2730, 9)

# %%
df.head()
# Out:
#                                                Title  \
# 0  Recent developments in bifunctional air electr...
# 1  The benefit of punishment sensitivity on motor...
# 2  MAGIC biomarkers predict long-term outcomes fo...
# 3  Are endocrine disrupting compounds environment...
# 4  Probabilistic regular grammar inference algori...
#
#                                             Abstract  \
# 0  © 2018 Hydrogen Energy Publications LLCUnitize...
# 1  © 2017 Wiley Periodicals, Inc.Objective: Human...
# 2  © 2018 by The American Society of Hematology.A...
# 3  © 2017 Elsevier Inc.Recent research on the eti...
# 4  © Proceedings of 2018 the 8th International Wo...
#
#                                               Author            Subject_Area  \
# 0                 Hunsom M.; Kaewsai D.; Kannan A.M.  2105; 2103; 3104; 2102
# 1  Manley H.; Beattie S.; Roberts R.; Lawrence G....                    3207
# 2  Major-Monfried H.; Renteria A.S.; Pawarode A.;...  1303; 2403; 2720; 1307
# 3            Moosa A.; Shu H.; Sarachana T.; Hu V.W.        1310; 2807; 2802
# 4                          Penpinun T.; Surarerks A.        1710; 1706; 1705
#
#   Publication_Date                                    Affiliations_ID  \
# 0       2018-11-15                                 60028190; 60004372
# 1       2018-06-01                                 60025779; 60028190
# 2       2018-06-21  60006297; 60028190; 60005036; 60005558; 600308...
# 3       2018-05-01                                 60025286; 60028190
# 4       2018-01-01                                           60028190
#
#                                           References  \
# 0  Chapter 9 – fuel cell system design; New promi...
# 1  Choking under pressure: Self-consciousness and...
# 2  Significant improvement in survival after unre...
# 3  Heterogeneous dysregulation of microRNAs acros...
# 4  Language identification in the limit; Bootstra...
#
#                                             Keywords   Filename
# 0  Bifunctional air electrode; Catalyst support; ...  201800282
# 1  anxiety; defensive distance; performance; rein...  201801350
# 2                                               None  201801162
# 3  Autism; Endocrine disrupting compounds; Epigen...  201801506
# 4  Grammar inference; Incremental technique; Prob...  201802383

# %%
df.to_csv('/Users/pookansmacbookpro/Documents/CEDT Computer Engineering/Sem1_2024/2110403_DataSci/Project/ExtractedData/2018.csv', encoding='utf-8' ,index=False)
