# %%
import pybliometrics.scopus as scopus
import numpy as np
import pandas as pd
import random
import time

# %%
seed = 7 # seed for NMF topic model
num_topics = 12
query = 'title-abs-key("engineering" AND "research" AND "innovation") AND PUBYEAR = 2018'
labels = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
vis_seed = 6 # seed for t-SNE visualization
vis_angle = 135 # rotation angle for visualization

# %%
scopus.init()
papers = scopus.ScopusSearch(query, subscriber=True, verbose=True, view='COMPLETE')
print(papers.results[0])
# Out:
# Document(eid='2-s2.0-85060060691', doi='10.1088/1757-899X/463/3/032081', pii=None, pubmed_id=None, title='Architectural-Typological Innovations as a Key Factor for Sustainable Development of Specially Protected Natural Areas', subtype='cp', subtypeDescription='Conference Paper', creator='Vavilova T.', afid='60021885', affilname='Samara State Technical University', affiliation_city='Samara', affiliation_country='Russian Federation', author_count='2', author_names='Vavilova, T.;Bakhareva, Y.', author_ids='57189346446;57205437615', author_afids='60021885;60021885', coverDate='2018-12-31', coverDisplayDate='31 December 2018', publicationName='IOP Conference Series: Materials Science and Engineering', issn='17578981', source_id='19700200831', eIssn='1757899X', aggregationType='Conference Proceeding', volume='463', issueIdentifier='3', article_number='032081', pageRange=None, description="The issues of improving the architectural solutions of the objects of infrastructure for specially protected natural areas of the Russian Federation considered from the point of view of tourist activity activation. Extensive international experience analyzed. The relationship investigated between the typological diversity of buildings and structures and the categories of territories, which is determined depending on the landscape value and the mode of operation (reserves, national parks, natural parks, nature sanctuary, natural monuments, arboretums and botanical gardens). The conclusions were that the development of scientific research and educational activities in natural areas and settlements with active tourist traffic should be associated with the design and construction of multifunctional buildings, saturation of areas with municipal and engineering facilities contributes for the safety of operation, the use of resource-saving technologies increases the comfort of people's stay.", authkeywords=None, citedby_count=4, openaccess=1, freetoread='publisherfree2read', freetoreadLabel='Bronze', fund_acr=None, fund_no='undefined', fund_sponsor=None)

# %%
df = pd.DataFrame(papers.results)

# %%
# สร้าง DataFrame เพื่อบันทึกเป็น CSV
data = []

for paper in papers.results:
    paper_dict = {
        "Title": paper.title,
        "Abstract": paper.description if hasattr(paper, 'description') else "",
        "Author": "; ".join(paper.author_names.split('; ')) if hasattr(paper, 'author_names') and paper.author_names else "",
        "Aggregation_Type": paper.aggregationType if hasattr(paper, 'aggregationType') else "",
        "Publisher": paper.publicationName if hasattr(paper, 'publicationName') else "",
        "Publication_Date": paper.coverDate if hasattr(paper, 'coverDate') else "",
        "Institutions": "; ".join(paper.affilname.split('; ')) if hasattr(paper, 'affilname') and paper.affilname else "",
        "Keywords": "; ".join(paper.authkeywords.split('|')) if hasattr(paper, 'authkeywords') and paper.authkeywords else "",
    }
    data.append(paper_dict)


df = pd.DataFrame(data)

output_file = "scopus_papers_2018_full_details.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

# %%
df2018 = pd.read_csv('scopus_papers_2018_full_details.csv')

# %%
df2018.head(10)
# Out:
#                                                Title  \
# 0  Architectural-Typological Innovations as a Key...
# 1       The bioeconomy of waste-to-energy production
# 2  Development of MR Clutch for a Prospective 5 D...
# 3  Educational innovations in Engineering educati...
# 4  Performance indicators to support the governan...
# 5  Optimized methodology using multi-choice quest...
# 6  Research on the Innovation of the Teaching Mod...
# 7  Research and Practice on the Cultivation of In...
# 8  Bringing scientific research education closer ...
# 9  Sustainable Livestock Development in the Borde...
#
#                                             Abstract  \
# 0  The issues of improving the architectural solu...
# 1  This chapter concerns the biobased materials f...
# 2  This paper presents an improved design approac...
# 3  The importance of promoting educational innova...
# 4  Research centres to be excellent, increasingly...
# 5  The introduction of the FCT Curricular Profile...
# 6  To promote the teaching reform of the ideologi...
# 7  Under the background of engineering education ...
# 8  In recent years, the International Genetically...
# 9  The purpose of this research is to provide inf...
#
#                                               Author       Aggregation_Type  \
# 0                         Vavilova, T.;Bakhareva, Y.  Conference Proceeding
# 1                               Dal-Poz, Maria Ester                   Book
# 2              Pisetskiy, Sergey;Kermani, Mehrdad R.  Conference Proceeding
# 3                       Guerra, Cecilia;Costa, Nilza  Conference Proceeding
# 4           Abreu, Antonio;Calado, J. M.F.;Dias, Ana  Conference Proceeding
# 5                          Oliveira, Filipe Tiago De  Conference Proceeding
# 6                            Huang, Weiyuan;Wei, Hao  Conference Proceeding
# 7   Tian, Siqing;Hou, Qiang;Wang, Yuenan;Du, Yunming  Conference Proceeding
# 8  Lü, Yuanye;Zhang, Yihao;Wang, Boxiang;Li, Chen...                Journal
# 9                        Muchlis, Dirwan;Nurcholis,   Conference Proceeding
#
#                                            Publisher Publication_Date  \
# 0  IOP Conference Series: Materials Science and E...       2018-12-31
# 1                              Waste-to-Energy (WtE)       2018-12-28
# 2  IEEE International Conference on Intelligent R...       2018-12-27
# 3  3rd International Conference of the Portuguese...       2018-12-27
# 4  3rd International Conference of the Portuguese...       2018-12-27
# 5  3rd International Conference of the Portuguese...       2018-12-27
# 6  Proceedings - 9th International Conference on ...       2018-12-26
# 7  Proceedings - 9th International Conference on ...       2018-12-26
# 8  Shengwu Gongcheng Xuebao/Chinese Journal of Bi...       2018-12-25
# 9                             E3S Web of Conferences       2018-12-21
#
#                                         Institutions  \
# 0                  Samara State Technical University
# 1                  Universidade Estadual de Campinas
# 2                                 Western University
# 3  Centro de Investigação Didática e Tecnologia n...
# 4  Instituto Superior de Engenharia de Lisboa;Ins...
# 5  Faculdade de Ciências e Tecnologia da Universi...
# 6       Shandong University of Finance and Economics
# 7                                 Jiamusi University
# 8                     Peking University;BGI Research
# 9                        Universitas Musamus Merauke
#
#                                             Keywords
# 0                                                NaN
# 1  Bioeconomy ;  Innovation ;  Networks ;  Patent...
# 2                                                NaN
# 3  Educational innovations ;  Engineering Educati...
# 4  Open-innovation ;  Organizational management ;...
# 5  FCT Curricular Profile ;  FCT NOVA ;  MCQ ;  M...
# 6  Big data ;  Ideological and political theory c...
# 7  Automation specialty ;  Engineering education ...
# 8  Genetic engineering ;  IGEM ;  International g...
# 9          Animal Science ;  Environment ;  Strategy
